# %%
import csv
import cv2
import itertools
import numpy as np
import pandas as pd
import os
import sys
import tempfile
import tqdm

from matplotlib import pyplot as plt
from matplotlib.collections import LineCollection

import tensorflow as tf
import tensorflow_hub as hub
from tensorflow import keras
import tensorflowjs as tfjs

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Download model from TF Hub and check out inference code from GitHub
# !wget -q -O movenet_thunder.tflite https://tfhub.dev/google/lite-model/movenet/singlepose/thunder/tflite/float16/4?lite-format=tflite
# !git clone https://github.com/tensorflow/examples.git
pose_sample_rpi_path = os.path.join(os.getcwd(), 'examples/lite/examples/pose_estimation/raspberry_pi')
sys.path.append(pose_sample_rpi_path)
# Out:
# zsh:1: no matches found: https://tfhub.dev/google/lite-model/movenet/singlepose/thunder/tflite/float16/4?lite-format=tflite
# fatal: destination path 'examples' already exists and is not an empty directory.

# %%
# Load MoveNet Thunder model
import utils
from data import BodyPart
from ml import Movenet
movenet = Movenet('movenet_thunder')

# Define function to run pose estimation using MoveNet Thunder.
# You'll apply MoveNet's cropping algorithm and run inference multiple times on
# the input image to improve pose estimation accuracy.
def detect(input_tensor, inference_count=3):
  """Runs detection on an input image.

  Args:
    input_tensor: A [height, width, 3] Tensor of type tf.float32.
      Note that height and width can be anything since the image will be
      immediately resized according to the needs of the model within this
      function.
    inference_count: Number of times the model should run repeatly on the
      same input image to improve detection accuracy.

  Returns:
    A Person entity detected by the MoveNet.SinglePose.
  """
  image_height, image_width, channel = input_tensor.shape

  # Detect pose using the full input image
  movenet.detect(input_tensor.numpy(), reset_crop_region=True)

  # Repeatedly using previous detection result to identify the region of
  # interest and only croping that region to improve detection accuracy
  for _ in range(inference_count - 1):
    person = movenet.detect(input_tensor.numpy(), 
                            reset_crop_region=False)

  return person

# %%
def draw_prediction_on_image(
    image, person, crop_region=None, close_figure=True,
    keep_input_size=False):
  """Draws the keypoint predictions on image.

  Args:
    image: An numpy array with shape [height, width, channel] representing the
      pixel values of the input image.
    person: A person entity returned from the MoveNet.SinglePose model.
    close_figure: Whether to close the plt figure after the function returns.
    keep_input_size: Whether to keep the size of the input image.

  Returns:
    An numpy array with shape [out_height, out_width, channel] representing the
    image overlaid with keypoint predictions.
  """
  # Draw the detection result on top of the image.
  image_np = utils.visualize(image, [person])

  # Plot the image with detection results.
  height, width, channel = image.shape
  aspect_ratio = float(width) / height
  fig, ax = plt.subplots(figsize=(12 * aspect_ratio, 12))
  im = ax.imshow(image_np)

  if close_figure:
    plt.close(fig)

  if not keep_input_size:
    image_np = utils.keep_aspect_ratio_resizer(image_np, (512, 512))

  return image_np

# %%
class MoveNetPreprocessor(object):
  """Helper class to preprocess pose sample images for classification."""

  def __init__(self,
               images_in_folder,
               images_out_folder,
               csvs_out_path):
    """Creates a preprocessor to detection pose from images and save as CSV.

    Args:
      images_in_folder: Path to the folder with the input images. It should
        follow this structure:
        yoga_poses
        |__ downdog
            |______ 00000128.jpg
            |______ 00000181.bmp
            |______ ...
        |__ goddess
            |______ 00000243.jpg
            |______ 00000306.jpg
            |______ ...
        ...
      images_out_folder: Path to write the images overlay with detected
        landmarks. These images are useful when you need to debug accuracy
        issues.
      csvs_out_path: Path to write the CSV containing the detected landmark
        coordinates and label of each image that can be used to train a pose
        classification model.
    """
    self._images_in_folder = images_in_folder
    self._images_out_folder = images_out_folder
    self._csvs_out_path = csvs_out_path
    self._messages = []

    # Create a temp dir to store the pose CSVs per class
    self._csvs_out_folder_per_class = tempfile.mkdtemp()

    # Get list of pose classes and print image statistics
    self._pose_class_names = sorted(
        [n for n in os.listdir(self._images_in_folder) if not n.startswith('.')]
        )

  def process(self, per_pose_class_limit=None, detection_threshold=0.1):
    """Preprocesses images in the given folder.
    Args:
      per_pose_class_limit: Number of images to load. As preprocessing usually
        takes time, this parameter can be specified to make the reduce of the
        dataset for testing.
      detection_threshold: Only keep images with all landmark confidence score
        above this threshold.
    """
    # Loop through the classes and preprocess its images
    for pose_class_name in self._pose_class_names:
      print('Preprocessing', pose_class_name, file=sys.stderr)

      # Paths for the pose class.
      images_in_folder = os.path.join(self._images_in_folder, pose_class_name)
      images_out_folder = os.path.join(self._images_out_folder, pose_class_name)
      csv_out_path = os.path.join(self._csvs_out_folder_per_class,
                                  pose_class_name + '.csv')
      if not os.path.exists(images_out_folder):
        os.makedirs(images_out_folder)

      # Detect landmarks in each image and write it to a CSV file
      with open(csv_out_path, 'w') as csv_out_file:
        csv_out_writer = csv.writer(csv_out_file, 
                                    delimiter=',', 
                                    quoting=csv.QUOTE_MINIMAL)
        # Get list of images
        image_names = sorted(
            [n for n in os.listdir(images_in_folder) if not n.startswith('.')])
        if per_pose_class_limit is not None:
          image_names = image_names[:per_pose_class_limit]

        valid_image_count = 0

        # Detect pose landmarks from each image
        for image_name in tqdm.tqdm(image_names):
          image_path = os.path.join(images_in_folder, image_name)

          try:
            image = tf.io.read_file(image_path)
            image = tf.io.decode_jpeg(image)
          except:
            self._messages.append('Skipped ' + image_path + '. Invalid image.')
            continue
          else:
            image = tf.io.read_file(image_path)
            image = tf.io.decode_jpeg(image)
            image_height, image_width, channel = image.shape

          # Skip images that isn't RGB because Movenet requires RGB images
          if channel != 3:
            self._messages.append('Skipped ' + image_path +
                                  '. Image isn\'t in RGB format.')
            continue
          person = detect(image)

          # Save landmarks if all landmarks were detected
          min_landmark_score = min(
              [keypoint.score for keypoint in person.keypoints])
          should_keep_image = min_landmark_score >= detection_threshold
          if not should_keep_image:
            self._messages.append('Skipped ' + image_path +
                                  '. No pose was confidentlly detected.')
            continue

          valid_image_count += 1

          # Draw the prediction result on top of the image for debugging later
          output_overlay = draw_prediction_on_image(
              image.numpy().astype(np.uint8), person, 
              close_figure=True, keep_input_size=True)

          # Write detection result into an image file
          output_frame = cv2.cvtColor(output_overlay, cv2.COLOR_RGB2BGR)
          cv2.imwrite(os.path.join(images_out_folder, image_name), output_frame)

          # Get landmarks and scale it to the same size as the input image
          pose_landmarks = np.array(
              [[keypoint.coordinate.x, keypoint.coordinate.y, keypoint.score]
                for keypoint in person.keypoints],
              dtype=np.float32)

          # Write the landmark coordinates to its per-class CSV file
          coordinates = pose_landmarks.flatten().astype(np.str).tolist()
          csv_out_writer.writerow([image_name] + coordinates)

        if not valid_image_count:
          raise RuntimeError(
              'No valid images found for the "{}" class.'
              .format(pose_class_name))

    # Print the error message collected during preprocessing.
    print('\n'.join(self._messages))

    # Combine all per-class CSVs into a single output file
    all_landmarks_df = self._all_landmarks_as_dataframe()
    all_landmarks_df.to_csv(self._csvs_out_path, index=False)

  def class_names(self):
    """List of classes found in the training dataset."""
    return self._pose_class_names

  def _all_landmarks_as_dataframe(self):
    """Merge all per-class CSVs into a single dataframe."""
    total_df = None
    for class_index, class_name in enumerate(self._pose_class_names):
      csv_out_path = os.path.join(self._csvs_out_folder_per_class,
                                  class_name + '.csv')
      per_class_df = pd.read_csv(csv_out_path, header=None)

      # Add the labels
      per_class_df['class_no'] = [class_index]*len(per_class_df)
      per_class_df['class_name'] = [class_name]*len(per_class_df)

      # Append the folder name to the filename column (first column)
      per_class_df[per_class_df.columns[0]] = (os.path.join(class_name, '') 
        + per_class_df[per_class_df.columns[0]].astype(str))

      if total_df is None:
        # For the first class, assign its data to the total dataframe
        total_df = per_class_df
      else:
        # Concatenate each class's data into the total dataframe
        total_df = pd.concat([total_df, per_class_df], axis=0)

    list_name = [[bodypart.name + '_x', bodypart.name + '_y', 
                  bodypart.name + '_score'] for bodypart in BodyPart] 
    header_name = []
    for columns_name in list_name:
      header_name += columns_name
    header_name = ['file_name'] + header_name
    header_map = {total_df.columns[i]: header_name[i] 
                  for i in range(len(header_name))}

    total_df.rename(header_map, axis=1, inplace=True)

    return total_df

# %%
test_image_url = "https://cdn.pixabay.com/photo/2017/03/03/17/30/yoga-2114512_960_720.jpg"
# !wget -O /tmp/image.jpeg {test_image_url}

if len(test_image_url):
  image = tf.io.read_file('/tmp/image.jpeg')
  image = tf.io.decode_jpeg(image)
  person = detect(image)
  _ = draw_prediction_on_image(image.numpy(), person, crop_region=None, 
                               close_figure=False, keep_input_size=True)
# Out:
# --2022-11-29 15:41:44--  https://cdn.pixabay.com/photo/2017/03/03/17/30/yoga-2114512_960_720.jpg
# Resolving cdn.pixabay.com (cdn.pixabay.com)... 2606:4700:4400::ac40:960c, 2606:4700:4400::6812:25f4, 104.18.37.244, ...
# Connecting to cdn.pixabay.com (cdn.pixabay.com)|2606:4700:4400::ac40:960c|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29024 (28K) [binary/octet-stream]
# Saving to: ‘/tmp/image.jpeg’
#
# /tmp/image.jpeg     100%[===================>]  28,34K  --.-KB/s    in 0s
#
# 2022-11-29 15:41:44 (96,5 MB/s) - ‘/tmp/image.jpeg’ saved [29024/29024]
# 2022-11-29 15:41:44.735280: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/borscs/.local/lib/python3.8/site-packages/cv2/../../lib64:
# 2022-11-29 15:41:44.735305: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-11-29 15:41:44.735321: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (borscs-GL552JX): /proc/driver/nvidia/version does not exist
# 2022-11-29 15:41:44.735684: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
is_skip_step_1 = False
use_custom_dataset = True
dataset_is_split = True

# %%
if use_custom_dataset:
  # ATTENTION:
  # You must edit these two lines to match your archive and images folder name:
  # !tar -xf YOUR_DATASET_ARCHIVE_NAME.tar
  # !unzip -q yoga_poses.zip
  dataset_in = 'yoga_poses'

  # You can leave the rest alone:
  if not os.path.isdir(dataset_in):
    raise Exception("dataset_in is not a valid directory")
  if dataset_is_split:
    IMAGES_ROOT = dataset_in
  else:
    dataset_out = 'split_' + dataset_in
    split_into_train_test(dataset_in, dataset_out, test_split=0.2)
    IMAGES_ROOT = dataset_out

# %%
if not is_skip_step_1:
  images_in_train_folder = os.path.join(IMAGES_ROOT, 'train')
  images_out_train_folder = 'poses_images_out_train'
  csvs_out_train_path = 'train_data.csv'

  preprocessor = MoveNetPreprocessor(
      images_in_folder=images_in_train_folder,
      images_out_folder=images_out_train_folder,
      csvs_out_path=csvs_out_train_path,
  )

  preprocessor.process(per_pose_class_limit=None)
# Out:
# Preprocessing chair
#   0%|         | 0/400 [00:00<?, ?it/s]/tmp/ipykernel_5272/1878308195.py:126: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   coordinates = pose_landmarks.flatten().astype(np.str).tolist()
# 100%|█| 400/400 [00:44<00:00,  8.93it/
# Preprocessing cobra
# 100%|█| 400/400 [00:42<00:00,  9.47it/
# Preprocessing dog
# 100%|█| 400/400 [00:42<00:00,  9.43it/
# Preprocessing no_pose
# 100%|█| 26/26 [00:03<00:00,  7.76it/s]
# Preprocessing shoudler_stand
# 100%|█| 50/50 [00:05<00:00,  8.49it/s]
# Preprocessing traingle
# 100%|█| 45/45 [00:06<00:00,  6.46it/s]
# Preprocessing tree
# 100%|█| 418/418 [00:49<00:00,  8.41it/
# Preprocessing warrior
# 100%|█| 400/400 [00:50<00:00,  7.95it/
# Skipped yoga_poses/train/chair/girl3_chair087_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair088_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair089_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair091.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair091_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair092.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair092_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair093.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair093_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair094.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair095_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair096.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair097.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair099.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair099_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair100.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair104.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair106.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair106_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair107_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair108_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair110.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair110_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair114.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair115.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair118.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair118_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair122.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair122_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair123.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair123_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair124.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair125.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair125_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair131.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair131_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair132.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair132_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair133.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair133_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair134.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair134_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair136.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair136_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair138.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair138_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair139.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair140_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair141_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/girl3_chair142.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/guy2_chair075_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/guy2_chair089.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/guy2_chair136.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/guy2_chair140.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/guy2_chair140_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/guy2_chair143.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/guy2_chair143_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/guy2_chair144.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/guy2_chair144_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/guy2_chair145.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/guy2_chair145_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/guy2_chair146.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/guy2_chair146_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/guy2_chair147_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/guy2_chair148_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/chair/guy_chair078_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra026.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra026_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra029.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra029_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra030.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra030_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra038.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra038_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra040.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra040_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra041.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra041_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra048.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra048_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra050.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra050_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra051.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra051_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra055.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra055_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra059.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra061.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra061_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra068.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra068_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra070.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra070_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra073_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra078_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra081.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra081_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra087.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra088.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra088_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra089.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra089_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra090.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra090_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra091.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra091_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra092.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra092_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra093.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra093_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra094.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra094_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra096.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra096_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra099.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra099_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra102.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra102_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra110.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra112.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra112_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra115.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra115_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra119.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra122.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra128.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra128_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra129.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra136.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra136_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl1_cobra140.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl2_cobra029.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl2_cobra029_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl2_cobra033_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl2_cobra035_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl2_cobra046.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl2_cobra050.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl2_cobra052_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl2_cobra053.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl2_cobra053_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl2_cobra055_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl2_cobra108.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl2_cobra117.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl2_cobra117_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl2_cobra120_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl2_cobra122_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl2_cobra127_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl2_cobra129.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl2_cobra129_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl2_cobra130_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl2_cobra133.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl2_cobra133_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl2_cobra136.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl2_cobra140.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl2_cobra140_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra028.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra028_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra030.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra030_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra032.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra032_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra039.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra039_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra040.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra040_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra051.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra051_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra052.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra052_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra058.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra058_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra060_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra062.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra062_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra064_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra068.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra068_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra072.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra072_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra076.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra076_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra078.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra078_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra079.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra079_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra082.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra082_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra088.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra088_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra092.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra092_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra097.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra098_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra099.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra099_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra101_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra107.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra118_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra126_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra129.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra129_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra130.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra130_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra132.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra134.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra134_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/girl3_cobra138.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/guy2_cobra034.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/guy2_cobra042.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/guy2_cobra043.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/guy2_cobra047.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/guy2_cobra053.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/guy2_cobra065.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/guy2_cobra075_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/guy2_cobra077.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/guy2_cobra078.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/guy2_cobra080.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/guy2_cobra080_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/guy2_cobra081.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/guy2_cobra081_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/guy2_cobra084.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/guy2_cobra088.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/guy2_cobra089.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/guy2_cobra102.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/guy2_cobra105.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/guy2_cobra108.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/guy2_cobra108_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/guy2_cobra110_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/guy2_cobra137_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/guy2_cobra139.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/cobra/guy2_cobra139_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl1_dog027.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl1_dog027_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl1_dog028.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl1_dog028_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl1_dog029_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl1_dog030.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl1_dog031_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl1_dog032.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl1_dog032_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl1_dog044_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl1_dog045_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl1_dog053_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl1_dog054_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl1_dog055_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl1_dog056_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl1_dog057_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog067_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog068_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog070_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog071_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog074_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog075.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog075_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog080.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog080_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog083.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog083_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog085.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog085_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog087.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog088.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog088_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog090.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog091.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog093.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog094.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog095.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog099.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog099_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog100.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog100_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog101.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog103.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog103_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog104.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog105.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog105_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog107.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog107_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl2_dog111.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog025.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog026.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog027.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog027_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog028.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog028_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog031.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog031_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog033.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog035.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog037.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog040.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog040_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog041.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog041_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog043_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog046_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog047.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog047_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog052.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog052_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog057_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog062.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog062_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog072.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog072_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog074.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog074_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog075.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog075_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog077.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog077_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog081.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog081_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog082.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog082_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog086.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog086_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog088.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog088_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog090.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog090_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog092.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog092_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog094.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog094_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog095.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog095_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog096.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog096_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog100.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog100_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog102.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog102_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog103.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog103_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog104.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog104_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog106.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog106_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog107.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog107_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog111.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/girl3_dog111_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/guy1_dog070.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/guy1_dog076.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/guy1_dog081_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/guy2_dog053_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/guy2_dog056_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/guy2_dog058_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/guy2_dog059_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/guy2_dog060_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/guy2_dog070.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/guy2_dog070_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/guy2_dog071.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/guy2_dog073_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/guy2_dog080_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/dog/guy2_dog082.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/no_pose/7.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/no_pose/7_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/shoudler_stand/360_F_42391109_24iiuvWtfCUMzVhws7HHmBrXrIuFs2nk.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/shoudler_stand/360_F_42391109_24iiuvWtfCUMzVhws7HHmBrXrIuFs2nk_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/shoudler_stand/365476-grt-How-to-Do-a-Shoulder-Stand-732x549-thumbnail.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/shoudler_stand/365476-grt-How-to-Do-a-Shoulder-Stand-732x549-thumbnail_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/shoudler_stand/full-length-shot-woman-practicing-yoga-standing-salamba-sarvangasana-exercise-supported-shoulder-stand-pose-gradient-197518339_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/shoudler_stand/istockphoto-489808151-612x612_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/shoudler_stand/sarvangasana.webp. Invalid image.
# Skipped yoga_poses/train/shoudler_stand/sarvangasana_flipped.webp. Invalid image.
# Skipped yoga_poses/train/traingle/Triangle-Yoga-Pose-61102-pixahive.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/traingle/Using-Yoga-Block-for-Triangle-Pose.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/traingle/Using-Yoga-Block-for-Triangle-Pose_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/traingle/offset_876963.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/traingle/triangle-pose-5-535x355-1.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/traingle/triangle_9437.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/traingle/triangle_9437_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/girl2_tree085_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/girl2_tree095_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/girl2_tree110_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/girl2_tree119.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/girl2_tree122.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/girl2_tree161.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/girl2_tree163.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/girl3_tree087_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/girl3_tree089_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/girl3_tree093_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/girl3_tree094_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/girl3_tree113_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/girl3_tree119_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/girl3_tree120_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/girl3_tree121_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/girl3_tree124_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/guy1_tree139.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/guy1_tree140.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/guy1_tree141.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/guy1_tree143.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/guy2_tree085.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/guy2_tree086.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/guy2_tree086_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/guy2_tree087.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/guy2_tree088.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/guy2_tree090.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/guy2_tree092.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/guy2_tree145.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/tree/guy2_tree147.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior046_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior049.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior053.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior064.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior064_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior066.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior066_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior067.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior067_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior072.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior072_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior075.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior075_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior077.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior077_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior080.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior083.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior084.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior084_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior087.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior087_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior089.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior089_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior093.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior093_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior094.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior094_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior095.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior095_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior098.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior098_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior099.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior099_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior100.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior100_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior103.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior108.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior108_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior109.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior109_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior111.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior111_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior112.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior112_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior113.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior113_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior114.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior114_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior116.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior117.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior123_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior125_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl1_warrior129_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior047.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior047_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior049.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior049_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior050.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior050_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior052.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior052_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior057.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior057_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior058.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior058_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior063.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior063_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior068.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior068_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior078_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior079.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior079_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior083.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior083_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior085.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior088.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior092.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior094_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior096.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior096_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior097.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior097_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior102.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior106.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl2_warrior108.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior042.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior042_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior043.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior043_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior047.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior047_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior049.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior049_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior050_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior051.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior051_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior054.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior056.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior057.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior057_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior061.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior061_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior066.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior066_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior067.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior067_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior073.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior073_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior074.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior074_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior075.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior075_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior079.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior085_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior087.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior087_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior089.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior089_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior090.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior090_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior091.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior091_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior092.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior092_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior094.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior094_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior095.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior095_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior096.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior096_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior100.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior100_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior103.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior107.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior107_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior115.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior115_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior117.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior117_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior119_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior127_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior134.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior134_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior140.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior140_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior143.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/girl3_warrior150_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior043.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior044_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior048.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior048_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior051.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior051_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior052.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior052_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior055.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior055_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior057.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior062.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior062_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior068.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior068_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior069.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior069_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior073.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior076.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior076_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior077.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior080.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior081.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior082.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior088.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior091.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior092.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior092_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior093.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior094.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior094_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior097.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior100_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior104_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior118.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior120.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior121.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior124.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior125.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior126.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior128_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior131.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior134.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior135.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior138.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior143.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior145.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy1_warrior148.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior048_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior051.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior051_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior054_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior057_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior059_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior065_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior066_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior077_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior086.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior094_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior100_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior111.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior118.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior122.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior129.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior131.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior131_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior135.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior135_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior137.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior137_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior139.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior139_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior145.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior145_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior148.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/train/warrior/guy2_warrior150_flipped.jpg. No pose was confidentlly detected.

# %%
if not is_skip_step_1:
  images_in_test_folder = os.path.join(IMAGES_ROOT, 'test')
  images_out_test_folder = 'poses_images_out_test'
  csvs_out_test_path = 'test_data.csv'

  preprocessor = MoveNetPreprocessor(
      images_in_folder=images_in_test_folder,
      images_out_folder=images_out_test_folder,
      csvs_out_path=csvs_out_test_path,
  )

  preprocessor.process(per_pose_class_limit=None)
# Out:
# Preprocessing chair
#   0%|         | 0/168 [00:00<?, ?it/s]/tmp/ipykernel_5272/1878308195.py:126: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   coordinates = pose_landmarks.flatten().astype(np.str).tolist()
# 100%|█| 168/168 [00:20<00:00,  8.02it/
# Preprocessing cobra
# 100%|█| 232/232 [00:28<00:00,  8.26it/
# Preprocessing dog
# 100%|█| 180/180 [00:22<00:00,  8.18it/
# Preprocessing no_pose
# 100%|███| 2/2 [00:00<00:00,  6.84it/s]
# Preprocessing shoudler_stand
# 100%|███| 9/9 [00:01<00:00,  7.61it/s]
# Preprocessing traingle
# 100%|█| 10/10 [00:01<00:00,  6.68it/s]
# Preprocessing tree
# 100%|█| 192/192 [00:22<00:00,  8.54it/
# Preprocessing warrior
# 100%|█| 218/218 [00:23<00:00,  9.13it/
# Skipped yoga_poses/test/cobra/guy3_cobra036_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra048.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra050.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra051.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra051_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra052.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra053.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra054.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra055.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra056.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra057.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra058.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra059.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra059_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra060.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra060_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra061_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra062.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra063_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra066_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra067_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra068_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra069.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra069_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra071_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra075.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra077.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra077_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra079_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra080_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra081.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra081_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra124.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra131.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra132.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra134.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra135.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/cobra/guy3_cobra136.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/dog/guy3_dog025.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/dog/guy3_dog026.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/dog/guy3_dog036.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/dog/guy3_dog042.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/dog/guy3_dog101_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/dog/guy3_dog102_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/dog/guy3_dog103_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/dog/guy3_dog104_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/dog/guy3_dog105_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/dog/guy3_dog106.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/dog/guy3_dog108.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/shoudler_stand/shoulderstand-elisha.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/tree/guy3_tree168_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/tree/guy3_tree175_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/tree/guy3_tree178_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/tree/guy3_tree179_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/tree/guy3_tree180_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior042.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior042_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior043.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior043_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior044.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior044_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior045.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior046.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior046_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior047.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior047_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior048.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior049_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior050.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior051.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior051_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior052.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior053.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior053_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior054.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior054_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior055.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior056.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior056_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior057_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior058_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior059.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior059_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior060.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior060_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior062.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior063.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior064_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior065.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior065_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior066.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior066_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior068.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior068_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior069_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior070.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior070_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior071.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior072.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior073.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior073_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior074.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior074_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior075.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior075_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior076.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior076_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior077.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior077_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior078_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior079.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior080.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior080_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior081.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior082.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior082_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior083.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior083_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior084.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior084_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior085.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior085_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior086.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior086_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior087.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior087_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior088.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior088_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior089.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior089_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior093_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior099_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior110_flipped.jpg. No pose was confidentlly detected.
# Skipped yoga_poses/test/warrior/guy3_warrior137.jpg. No pose was confidentlly detected.

# %%
def load_pose_landmarks(csv_path):
  """Loads a CSV created by MoveNetPreprocessor.

  Returns:
    X: Detected landmark coordinates and scores of shape (N, 17 * 3)
    y: Ground truth labels of shape (N, label_count)
    classes: The list of all class names found in the dataset
    dataframe: The CSV loaded as a Pandas dataframe features (X) and ground
      truth labels (y) to use later to train a pose classification model.
  """

  # Load the CSV file
  dataframe = pd.read_csv(csv_path)
  df_to_process = dataframe.copy()

  # Drop the file_name columns as you don't need it during training.
  df_to_process.drop(columns=['file_name'], inplace=True)

  # Extract the list of class names
  classes = df_to_process.pop('class_name').unique()

  # Extract the labels
  y = df_to_process.pop('class_no')

  # Convert the input features and labels into the correct format for training.
  X = df_to_process.astype('float64')
  y = keras.utils.to_categorical(y)

  return X, y, classes, dataframe

# %%
# Load the train data
X, y, class_names, _ = load_pose_landmarks(csvs_out_train_path)

# Split training data (X, y) into (X_train, y_train) and (X_val, y_val)
X_train, X_val, y_train, y_val = train_test_split(X, y,
                                                  test_size=0.15)

# %%
# Load the test data
X_test, y_test, _, df_test = load_pose_landmarks(csvs_out_test_path)

# %%
def get_center_point(landmarks, left_bodypart, right_bodypart):
  """Calculates the center point of the two given landmarks."""

  left = tf.gather(landmarks, left_bodypart.value, axis=1)
  right = tf.gather(landmarks, right_bodypart.value, axis=1)
  center = left * 0.5 + right * 0.5
  return center


def get_pose_size(landmarks, torso_size_multiplier=2.5):
  """Calculates pose size.
  
  It is the maximum of two values:
    * Torso size multiplied by `torso_size_multiplier`
    * Maximum distance from pose center to any pose landmark
  """
  # Hips center
  hips_center = get_center_point(landmarks, BodyPart.LEFT_HIP, 
                                 BodyPart.RIGHT_HIP)

  # Shoulders center
  shoulders_center = get_center_point(landmarks, BodyPart.LEFT_SHOULDER,
                                      BodyPart.RIGHT_SHOULDER)

  # Torso size as the minimum body size
  torso_size = tf.linalg.norm(shoulders_center - hips_center)

  # Pose center
  pose_center_new = get_center_point(landmarks, BodyPart.LEFT_HIP, 
                                     BodyPart.RIGHT_HIP)
  pose_center_new = tf.expand_dims(pose_center_new, axis=1)
  # Broadcast the pose center to the same size as the landmark vector to
  # perform substraction
  pose_center_new = tf.broadcast_to(pose_center_new,
                                    [tf.size(landmarks) // (17*2), 17, 2])

  # Dist to pose center
  d = tf.gather(landmarks - pose_center_new, 0, axis=0,
                name="dist_to_pose_center")
  # Max dist to pose center
  max_dist = tf.reduce_max(tf.linalg.norm(d, axis=0))

  # Normalize scale
  pose_size = tf.maximum(torso_size * torso_size_multiplier, max_dist)

  return pose_size


def normalize_pose_landmarks(landmarks):
  """Normalizes the landmarks translation by moving the pose center to (0,0) and
  scaling it to a constant pose size.
  """
  # Move landmarks so that the pose center becomes (0,0)
  pose_center = get_center_point(landmarks, BodyPart.LEFT_HIP, 
                                 BodyPart.RIGHT_HIP)
  pose_center = tf.expand_dims(pose_center, axis=1)
  # Broadcast the pose center to the same size as the landmark vector to perform
  # substraction
  pose_center = tf.broadcast_to(pose_center, 
                                [tf.size(landmarks) // (17*2), 17, 2])
  landmarks = landmarks - pose_center

  # Scale the landmarks to a constant pose size
  pose_size = get_pose_size(landmarks)
  landmarks /= pose_size

  return landmarks


def landmarks_to_embedding(landmarks_and_scores):
  """Converts the input landmarks into a pose embedding."""
  # Reshape the flat input into a matrix with shape=(17, 3)
  reshaped_inputs = keras.layers.Reshape((17, 3))(landmarks_and_scores)

  # Normalize landmarks 2D
  landmarks = normalize_pose_landmarks(reshaped_inputs[:, :, :2])

  # Flatten the normalized landmark coordinates into a vector
  embedding = keras.layers.Flatten()(landmarks)

  return embedding

# %%
# Define the model
inputs = tf.keras.Input(shape=(51))
embedding = landmarks_to_embedding(inputs)

layer = keras.layers.Dense(128, activation=tf.nn.relu6)(embedding)
layer = keras.layers.Dropout(0.5)(layer)
layer = keras.layers.Dense(64, activation=tf.nn.relu6)(layer)
layer = keras.layers.Dropout(0.5)(layer)
outputs = keras.layers.Dense(len(class_names), activation="softmax")(layer)

model = keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 51)]         0           []
#
#  reshape (Reshape)              (None, 17, 3)        0           ['input_1[0][0]']
#
#  tf.__operators__.getitem (Slic  (None, 17, 2)       0           ['reshape[0][0]']
#  ingOpLambda)
#
#  tf.compat.v1.gather (TFOpLambd  (None, 2)           0           ['tf.__operators__.getitem[0][0]'
#  a)                                                              ]
#
#  tf.compat.v1.gather_1 (TFOpLam  (None, 2)           0           ['tf.__operators__.getitem[0][0]'
#  bda)                                                            ]
#
#  tf.math.multiply (TFOpLambda)  (None, 2)            0           ['tf.compat.v1.gather[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 2)           0           ['tf.compat.v1.gather_1[0][0]']
#  )
#
#  tf.__operators__.add (TFOpLamb  (None, 2)           0           ['tf.math.multiply[0][0]',
#  da)                                                              'tf.math.multiply_1[0][0]']
#
#  tf.compat.v1.size (TFOpLambda)  ()                  0           ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  tf.expand_dims (TFOpLambda)    (None, 1, 2)         0           ['tf.__operators__.add[0][0]']
#
#  tf.compat.v1.floor_div (TFOpLa  ()                  0           ['tf.compat.v1.size[0][0]']
#  mbda)
#
#  tf.broadcast_to (TFOpLambda)   (None, 17, 2)        0           ['tf.expand_dims[0][0]',
#                                                                   'tf.compat.v1.floor_div[0][0]']
#
#  tf.math.subtract (TFOpLambda)  (None, 17, 2)        0           ['tf.__operators__.getitem[0][0]'
#                                                                  , 'tf.broadcast_to[0][0]']
#
#  tf.compat.v1.gather_6 (TFOpLam  (None, 2)           0           ['tf.math.subtract[0][0]']
#  bda)
#
#  tf.compat.v1.gather_7 (TFOpLam  (None, 2)           0           ['tf.math.subtract[0][0]']
#  bda)
#
#  tf.math.multiply_6 (TFOpLambda  (None, 2)           0           ['tf.compat.v1.gather_6[0][0]']
#  )
#
#  tf.math.multiply_7 (TFOpLambda  (None, 2)           0           ['tf.compat.v1.gather_7[0][0]']
#  )
#
#  tf.__operators__.add_3 (TFOpLa  (None, 2)           0           ['tf.math.multiply_6[0][0]',
#  mbda)                                                            'tf.math.multiply_7[0][0]']
#
#  tf.compat.v1.size_1 (TFOpLambd  ()                  0           ['tf.math.subtract[0][0]']
#  a)
#
#  tf.compat.v1.gather_4 (TFOpLam  (None, 2)           0           ['tf.math.subtract[0][0]']
#  bda)
#
#  tf.compat.v1.gather_5 (TFOpLam  (None, 2)           0           ['tf.math.subtract[0][0]']
#  bda)
#
#  tf.compat.v1.gather_2 (TFOpLam  (None, 2)           0           ['tf.math.subtract[0][0]']
#  bda)
#
#  tf.compat.v1.gather_3 (TFOpLam  (None, 2)           0           ['tf.math.subtract[0][0]']
#  bda)
#
#  tf.expand_dims_1 (TFOpLambda)  (None, 1, 2)         0           ['tf.__operators__.add_3[0][0]']
#
#  tf.compat.v1.floor_div_1 (TFOp  ()                  0           ['tf.compat.v1.size_1[0][0]']
#  Lambda)
#
#  tf.math.multiply_4 (TFOpLambda  (None, 2)           0           ['tf.compat.v1.gather_4[0][0]']
#  )
#
#  tf.math.multiply_5 (TFOpLambda  (None, 2)           0           ['tf.compat.v1.gather_5[0][0]']
#  )
#
#  tf.math.multiply_2 (TFOpLambda  (None, 2)           0           ['tf.compat.v1.gather_2[0][0]']
#  )
#
#  tf.math.multiply_3 (TFOpLambda  (None, 2)           0           ['tf.compat.v1.gather_3[0][0]']
#  )
#
#  tf.broadcast_to_1 (TFOpLambda)  (None, 17, 2)       0           ['tf.expand_dims_1[0][0]',
#                                                                   'tf.compat.v1.floor_div_1[0][0]'
#                                                                  ]
#
#  tf.__operators__.add_2 (TFOpLa  (None, 2)           0           ['tf.math.multiply_4[0][0]',
#  mbda)                                                            'tf.math.multiply_5[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 2)           0           ['tf.math.multiply_2[0][0]',
#  mbda)                                                            'tf.math.multiply_3[0][0]']
#
#  tf.math.subtract_2 (TFOpLambda  (None, 17, 2)       0           ['tf.math.subtract[0][0]',
#  )                                                                'tf.broadcast_to_1[0][0]']
#
#  tf.math.subtract_1 (TFOpLambda  (None, 2)           0           ['tf.__operators__.add_2[0][0]',
#  )                                                                'tf.__operators__.add_1[0][0]']
#
#  tf.compat.v1.gather_8 (TFOpLam  (17, 2)             0           ['tf.math.subtract_2[0][0]']
#  bda)
#
#  tf.compat.v1.norm (TFOpLambda)  ()                  0           ['tf.math.subtract_1[0][0]']
#
#  tf.compat.v1.norm_1 (TFOpLambd  (2,)                0           ['tf.compat.v1.gather_8[0][0]']
#  a)
#
#  tf.math.multiply_8 (TFOpLambda  ()                  0           ['tf.compat.v1.norm[0][0]']
#  )
#
#  tf.math.reduce_max (TFOpLambda  ()                  0           ['tf.compat.v1.norm_1[0][0]']
#  )
#
#  tf.math.maximum (TFOpLambda)   ()                   0           ['tf.math.multiply_8[0][0]',
#                                                                   'tf.math.reduce_max[0][0]']
#
#  tf.math.truediv (TFOpLambda)   (None, 17, 2)        0           ['tf.math.subtract[0][0]',
#                                                                   'tf.math.maximum[0][0]']
#
#  flatten (Flatten)              (None, 34)           0           ['tf.math.truediv[0][0]']
#
#  dense (Dense)                  (None, 128)          4480        ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 128)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 64)           8256        ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 64)           0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 8)            520         ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 13,256
# Trainable params: 13,256
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Add a checkpoint callback to store the checkpoint that has the highest
# validation accuracy.
checkpoint_path = "weights.best.hdf5"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_path,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True,
                             mode='max')
earlystopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', 
                                              patience=20)

# Start training
history = model.fit(X_train, y_train,
                    epochs=200,
                    batch_size=16,
                    validation_data=(X_val, y_val),
                    callbacks=[checkpoint, earlystopping])
# Out:
# Epoch 1/200
# 59/81 [====================>.........] - ETA: 0s - loss: 1.8469 - accuracy: 0.3941
# Epoch 1: val_accuracy improved from -inf to 0.48018, saving model to weights.best.hdf5
# 81/81 [==============================] - 1s 6ms/step - loss: 1.7639 - accuracy: 0.4050 - val_loss: 1.3293 - val_accuracy: 0.4802
# Epoch 2/200
# 79/81 [============================>.] - ETA: 0s - loss: 1.2975 - accuracy: 0.5063
# Epoch 2: val_accuracy improved from 0.48018 to 0.64758, saving model to weights.best.hdf5
# 81/81 [==============================] - 0s 3ms/step - loss: 1.2904 - accuracy: 0.5078 - val_loss: 1.0175 - val_accuracy: 0.6476
# Epoch 3/200
# 59/81 [====================>.........] - ETA: 0s - loss: 1.1280 - accuracy: 0.5371
# Epoch 3: val_accuracy improved from 0.64758 to 0.72687, saving model to weights.best.hdf5
# 81/81 [==============================] - 0s 2ms/step - loss: 1.1137 - accuracy: 0.5436 - val_loss: 0.8585 - val_accuracy: 0.7269
# Epoch 4/200
# 56/81 [===================>..........] - ETA: 0s - loss: 0.9804 - accuracy: 0.6138
# Epoch 4: val_accuracy improved from 0.72687 to 0.75330, saving model to weights.best.hdf5
# 81/81 [==============================] - 0s 3ms/step - loss: 0.9682 - accuracy: 0.6199 - val_loss: 0.7465 - val_accuracy: 0.7533
# Epoch 5/200
# 77/81 [===========================>..] - ETA: 0s - loss: 0.8779 - accuracy: 0.6567
# Epoch 5: val_accuracy improved from 0.75330 to 0.82819, saving model to weights.best.hdf5
# 81/81 [==============================] - 0s 3ms/step - loss: 0.8764 - accuracy: 0.6589 - val_loss: 0.6510 - val_accuracy: 0.8282
# Epoch 6/200
# 57/81 [====================>.........] - ETA: 0s - loss: 0.8295 - accuracy: 0.6732
# Epoch 6: val_accuracy improved from 0.82819 to 0.84582, saving model to weights.best.hdf5
# 81/81 [==============================] - 0s 3ms/step - loss: 0.8014 - accuracy: 0.6963 - val_loss: 0.5782 - val_accuracy: 0.8458
# Epoch 7/200
# 81/81 [==============================] - ETA: 0s - loss: 0.7225 - accuracy: 0.7196
# Epoch 7: val_accuracy improved from 0.84582 to 0.86784, saving model to weights.best.hdf5
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7225 - accuracy: 0.7196 - val_loss: 0.5241 - val_accuracy: 0.8678
# Epoch 8/200
# 54/81 [===================>..........] - ETA: 0s - loss: 0.6928 - accuracy: 0.7454
# Epoch 8: val_accuracy improved from 0.86784 to 0.87225, saving model to weights.best.hdf5
# 81/81 [==============================] - 0s 3ms/step - loss: 0.6717 - accuracy: 0.7445 - val_loss: 0.4732 - val_accuracy: 0.8722
# Epoch 9/200
# 64/81 [======================>.......] - ETA: 0s - loss: 0.6130 - accuracy: 0.7715
# Epoch 9: val_accuracy did not improve from 0.87225
# 81/81 [==============================] - 0s 2ms/step - loss: 0.6080 - accuracy: 0.7765 - val_loss: 0.4282 - val_accuracy: 0.8546
# Epoch 10/200
# 55/81 [===================>..........] - ETA: 0s - loss: 0.5906 - accuracy: 0.7807
# Epoch 10: val_accuracy did not improve from 0.87225
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5764 - accuracy: 0.7827 - val_loss: 0.4151 - val_accuracy: 0.8502
# Epoch 11/200
# 61/81 [=====================>........] - ETA: 0s - loss: 0.5404 - accuracy: 0.8125
# Epoch 11: val_accuracy improved from 0.87225 to 0.91630, saving model to weights.best.hdf5
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5418 - accuracy: 0.8139 - val_loss: 0.3547 - val_accuracy: 0.9163
# Epoch 12/200
# 63/81 [======================>.......] - ETA: 0s - loss: 0.4919 - accuracy: 0.8224
# Epoch 12: val_accuracy improved from 0.91630 to 0.93392, saving model to weights.best.hdf5
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4946 - accuracy: 0.8232 - val_loss: 0.3273 - val_accuracy: 0.9339
# Epoch 13/200
# 66/81 [=======================>......] - ETA: 0s - loss: 0.4729 - accuracy: 0.8267
# Epoch 13: val_accuracy did not improve from 0.93392
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4718 - accuracy: 0.8279 - val_loss: 0.3004 - val_accuracy: 0.9251
# Epoch 14/200
# 55/81 [===================>..........] - ETA: 0s - loss: 0.4656 - accuracy: 0.8409
# Epoch 14: val_accuracy did not improve from 0.93392
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4681 - accuracy: 0.8427 - val_loss: 0.2906 - val_accuracy: 0.9295
# Epoch 15/200
# 53/81 [==================>...........] - ETA: 0s - loss: 0.4111 - accuracy: 0.8443
# Epoch 15: val_accuracy improved from 0.93392 to 0.94273, saving model to weights.best.hdf5
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4207 - accuracy: 0.8442 - val_loss: 0.2708 - val_accuracy: 0.9427
# Epoch 16/200
# 62/81 [=====================>........] - ETA: 0s - loss: 0.4121 - accuracy: 0.8569
# Epoch 16: val_accuracy improved from 0.94273 to 0.94714, saving model to weights.best.hdf5
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4308 - accuracy: 0.8567 - val_loss: 0.2536 - val_accuracy: 0.9471
# Epoch 17/200
# 57/81 [====================>.........] - ETA: 0s - loss: 0.4058 - accuracy: 0.8476
# Epoch 17: val_accuracy improved from 0.94714 to 0.95154, saving model to weights.best.hdf5
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3788 - accuracy: 0.8629 - val_loss: 0.2365 - val_accuracy: 0.9515
# Epoch 18/200
# 63/81 [======================>.......] - ETA: 0s - loss: 0.3698 - accuracy: 0.8621
# Epoch 18: val_accuracy did not improve from 0.95154
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3689 - accuracy: 0.8653 - val_loss: 0.2184 - val_accuracy: 0.9515
# Epoch 19/200
# 63/81 [======================>.......] - ETA: 0s - loss: 0.3647 - accuracy: 0.8661
# Epoch 19: val_accuracy did not improve from 0.95154
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3717 - accuracy: 0.8668 - val_loss: 0.2065 - val_accuracy: 0.9515
# Epoch 20/200
# 67/81 [=======================>......] - ETA: 0s - loss: 0.3221 - accuracy: 0.8890
# Epoch 20: val_accuracy did not improve from 0.95154
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3245 - accuracy: 0.8855 - val_loss: 0.1942 - val_accuracy: 0.9515
# Epoch 21/200
# 60/81 [=====================>........] - ETA: 0s - loss: 0.3295 - accuracy: 0.8823
# Epoch 21: val_accuracy did not improve from 0.95154
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3404 - accuracy: 0.8847 - val_loss: 0.1939 - val_accuracy: 0.9427
# Epoch 22/200
# 64/81 [======================>.......] - ETA: 0s - loss: 0.3063 - accuracy: 0.9014
# Epoch 22: val_accuracy did not improve from 0.95154
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3043 - accuracy: 0.9042 - val_loss: 0.1827 - val_accuracy: 0.9515
# Epoch 23/200
# 64/81 [======================>.......] - ETA: 0s - loss: 0.3118 - accuracy: 0.8916
# Epoch 23: val_accuracy improved from 0.95154 to 0.95595, saving model to weights.best.hdf5
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3156 - accuracy: 0.8949 - val_loss: 0.1713 - val_accuracy: 0.9559
# Epoch 24/200
# 68/81 [========================>.....] - ETA: 0s - loss: 0.2909 - accuracy: 0.9072
# Epoch 24: val_accuracy did not improve from 0.95595
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2855 - accuracy: 0.9065 - val_loss: 0.1710 - val_accuracy: 0.9515
# Epoch 25/200
# 61/81 [=====================>........] - ETA: 0s - loss: 0.2842 - accuracy: 0.9119
# Epoch 25: val_accuracy improved from 0.95595 to 0.96035, saving model to weights.best.hdf5
# 81/81 [==============================] - 0s 3ms/step - loss: 0.2809 - accuracy: 0.9073 - val_loss: 0.1596 - val_accuracy: 0.9604
# Epoch 26/200
# 66/81 [=======================>......] - ETA: 0s - loss: 0.2812 - accuracy: 0.9119
# Epoch 26: val_accuracy did not improve from 0.96035
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2782 - accuracy: 0.9097 - val_loss: 0.1456 - val_accuracy: 0.9604
# Epoch 27/200
# 61/81 [=====================>........] - ETA: 0s - loss: 0.2913 - accuracy: 0.9098
# Epoch 27: val_accuracy did not improve from 0.96035
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2812 - accuracy: 0.9128 - val_loss: 0.1536 - val_accuracy: 0.9604
# Epoch 28/200
# 78/81 [===========================>..] - ETA: 0s - loss: 0.2332 - accuracy: 0.9223
# Epoch 28: val_accuracy did not improve from 0.96035
# 81/81 [==============================] - 0s 3ms/step - loss: 0.2357 - accuracy: 0.9221 - val_loss: 0.1536 - val_accuracy: 0.9604
# Epoch 29/200
# 52/81 [==================>...........] - ETA: 0s - loss: 0.2729 - accuracy: 0.9050
# Epoch 29: val_accuracy improved from 0.96035 to 0.96476, saving model to weights.best.hdf5
# 81/81 [==============================] - 0s 3ms/step - loss: 0.2598 - accuracy: 0.9159 - val_loss: 0.1347 - val_accuracy: 0.9648
# Epoch 30/200
# 77/81 [===========================>..] - ETA: 0s - loss: 0.2577 - accuracy: 0.9302
# Epoch 30: val_accuracy did not improve from 0.96476
# 81/81 [==============================] - 0s 3ms/step - loss: 0.2548 - accuracy: 0.9315 - val_loss: 0.1444 - val_accuracy: 0.9559
# Epoch 31/200
# 70/81 [========================>.....] - ETA: 0s - loss: 0.2528 - accuracy: 0.9223
# Epoch 31: val_accuracy did not improve from 0.96476
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2437 - accuracy: 0.9260 - val_loss: 0.1389 - val_accuracy: 0.9648
# Epoch 32/200
# 69/81 [========================>.....] - ETA: 0s - loss: 0.2529 - accuracy: 0.9176
# Epoch 32: val_accuracy did not improve from 0.96476
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2534 - accuracy: 0.9190 - val_loss: 0.1237 - val_accuracy: 0.9648
# Epoch 33/200
# 64/81 [======================>.......] - ETA: 0s - loss: 0.2168 - accuracy: 0.9316
# Epoch 33: val_accuracy improved from 0.96476 to 0.97357, saving model to weights.best.hdf5
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2247 - accuracy: 0.9221 - val_loss: 0.1187 - val_accuracy: 0.9736
# Epoch 34/200
# 68/81 [========================>.....] - ETA: 0s - loss: 0.2155 - accuracy: 0.9357
# Epoch 34: val_accuracy did not improve from 0.97357
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2233 - accuracy: 0.9330 - val_loss: 0.1151 - val_accuracy: 0.9648
# Epoch 35/200
# 75/81 [==========================>...] - ETA: 0s - loss: 0.2043 - accuracy: 0.9325
# Epoch 35: val_accuracy did not improve from 0.97357
# 81/81 [==============================] - 0s 3ms/step - loss: 0.2058 - accuracy: 0.9330 - val_loss: 0.1165 - val_accuracy: 0.9648
# Epoch 36/200
# 62/81 [=====================>........] - ETA: 0s - loss: 0.2156 - accuracy: 0.9284
# Epoch 36: val_accuracy did not improve from 0.97357
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2086 - accuracy: 0.9330 - val_loss: 0.1245 - val_accuracy: 0.9604
# Epoch 37/200
# 66/81 [=======================>......] - ETA: 0s - loss: 0.1914 - accuracy: 0.9441
# Epoch 37: val_accuracy did not improve from 0.97357
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2091 - accuracy: 0.9361 - val_loss: 0.1057 - val_accuracy: 0.9692
# Epoch 38/200
# 66/81 [=======================>......] - ETA: 0s - loss: 0.1772 - accuracy: 0.9394
# Epoch 38: val_accuracy did not improve from 0.97357
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1837 - accuracy: 0.9346 - val_loss: 0.1104 - val_accuracy: 0.9559
# Epoch 39/200
# 67/81 [=======================>......] - ETA: 0s - loss: 0.1948 - accuracy: 0.9356
# Epoch 39: val_accuracy did not improve from 0.97357
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2033 - accuracy: 0.9322 - val_loss: 0.0990 - val_accuracy: 0.9692
# Epoch 40/200
# 63/81 [======================>.......] - ETA: 0s - loss: 0.1949 - accuracy: 0.9315
# Epoch 40: val_accuracy did not improve from 0.97357
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2026 - accuracy: 0.9307 - val_loss: 0.1010 - val_accuracy: 0.9736
# Epoch 41/200
# 67/81 [=======================>......] - ETA: 0s - loss: 0.1780 - accuracy: 0.9375
# Epoch 41: val_accuracy did not improve from 0.97357
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1773 - accuracy: 0.9416 - val_loss: 0.0929 - val_accuracy: 0.9736
# Epoch 42/200
# 57/81 [====================>.........] - ETA: 0s - loss: 0.2093 - accuracy: 0.9298
# Epoch 42: val_accuracy did not improve from 0.97357
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1901 - accuracy: 0.9393 - val_loss: 0.0938 - val_accuracy: 0.9692
# Epoch 43/200
# 67/81 [=======================>......] - ETA: 0s - loss: 0.1524 - accuracy: 0.9580
# Epoch 43: val_accuracy did not improve from 0.97357
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1522 - accuracy: 0.9556 - val_loss: 0.0922 - val_accuracy: 0.9648
# Epoch 44/200
# 56/81 [===================>..........] - ETA: 0s - loss: 0.1435 - accuracy: 0.9520
# Epoch 44: val_accuracy did not improve from 0.97357
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1545 - accuracy: 0.9486 - val_loss: 0.0830 - val_accuracy: 0.9736
# Epoch 45/200
# 55/81 [===================>..........] - ETA: 0s - loss: 0.1655 - accuracy: 0.9477
# Epoch 45: val_accuracy did not improve from 0.97357
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1768 - accuracy: 0.9455 - val_loss: 0.0891 - val_accuracy: 0.9736
# Epoch 46/200
# 64/81 [======================>.......] - ETA: 0s - loss: 0.1735 - accuracy: 0.9492
# Epoch 46: val_accuracy did not improve from 0.97357
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1653 - accuracy: 0.9525 - val_loss: 0.0851 - val_accuracy: 0.9692
# Epoch 47/200
# 57/81 [====================>.........] - ETA: 0s - loss: 0.1561 - accuracy: 0.9572
# Epoch 47: val_accuracy did not improve from 0.97357
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1690 - accuracy: 0.9525 - val_loss: 0.0917 - val_accuracy: 0.9692
# Epoch 48/200
# 60/81 [=====================>........] - ETA: 0s - loss: 0.1740 - accuracy: 0.9448
# Epoch 48: val_accuracy did not improve from 0.97357
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1698 - accuracy: 0.9447 - val_loss: 0.0880 - val_accuracy: 0.9692
# Epoch 49/200
# 59/81 [====================>.........] - ETA: 0s - loss: 0.1826 - accuracy: 0.9375
# Epoch 49: val_accuracy did not improve from 0.97357
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1824 - accuracy: 0.9408 - val_loss: 0.0852 - val_accuracy: 0.9736
# Epoch 50/200
# 60/81 [=====================>........] - ETA: 0s - loss: 0.1674 - accuracy: 0.9490
# Epoch 50: val_accuracy did not improve from 0.97357
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1666 - accuracy: 0.9486 - val_loss: 0.0922 - val_accuracy: 0.9692
# Epoch 51/200
# 63/81 [======================>.......] - ETA: 0s - loss: 0.1614 - accuracy: 0.9454
# Epoch 51: val_accuracy did not improve from 0.97357
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1589 - accuracy: 0.9478 - val_loss: 0.0841 - val_accuracy: 0.9736
# Epoch 52/200
# 53/81 [==================>...........] - ETA: 0s - loss: 0.1782 - accuracy: 0.9340
# Epoch 52: val_accuracy did not improve from 0.97357
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1628 - accuracy: 0.9431 - val_loss: 0.0801 - val_accuracy: 0.9736
# Epoch 53/200
# 67/81 [=======================>......] - ETA: 0s - loss: 0.1414 - accuracy: 0.9562
# Epoch 53: val_accuracy improved from 0.97357 to 0.97797, saving model to weights.best.hdf5
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1415 - accuracy: 0.9564 - val_loss: 0.0717 - val_accuracy: 0.9780
# Epoch 54/200
# 62/81 [=====================>........] - ETA: 0s - loss: 0.1437 - accuracy: 0.9466
# Epoch 54: val_accuracy improved from 0.97797 to 0.98238, saving model to weights.best.hdf5
# 81/81 [==============================] - 0s 3ms/step - loss: 0.1373 - accuracy: 0.9494 - val_loss: 0.0754 - val_accuracy: 0.9824
# Epoch 55/200
# 64/81 [======================>.......] - ETA: 0s - loss: 0.1529 - accuracy: 0.9561
# Epoch 55: val_accuracy did not improve from 0.98238
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1550 - accuracy: 0.9540 - val_loss: 0.0757 - val_accuracy: 0.9780
# Epoch 56/200
# 64/81 [======================>.......] - ETA: 0s - loss: 0.1754 - accuracy: 0.9453
# Epoch 56: val_accuracy did not improve from 0.98238
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1775 - accuracy: 0.9455 - val_loss: 0.0794 - val_accuracy: 0.9780
# Epoch 57/200
# 64/81 [======================>.......] - ETA: 0s - loss: 0.1380 - accuracy: 0.9570
# Epoch 57: val_accuracy did not improve from 0.98238
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1488 - accuracy: 0.9548 - val_loss: 0.0687 - val_accuracy: 0.9780
# Epoch 58/200
# 58/81 [====================>.........] - ETA: 0s - loss: 0.1642 - accuracy: 0.9515
# Epoch 58: val_accuracy did not improve from 0.98238
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1550 - accuracy: 0.9564 - val_loss: 0.0783 - val_accuracy: 0.9780
# Epoch 59/200
# 68/81 [========================>.....] - ETA: 0s - loss: 0.1571 - accuracy: 0.9476
# Epoch 59: val_accuracy did not improve from 0.98238
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1527 - accuracy: 0.9509 - val_loss: 0.0677 - val_accuracy: 0.9824
# Epoch 60/200
# 61/81 [=====================>........] - ETA: 0s - loss: 0.1621 - accuracy: 0.9477
# Epoch 60: val_accuracy did not improve from 0.98238
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1532 - accuracy: 0.9502 - val_loss: 0.0748 - val_accuracy: 0.9736
# Epoch 61/200
# 65/81 [=======================>......] - ETA: 0s - loss: 0.1431 - accuracy: 0.9519
# Epoch 61: val_accuracy did not improve from 0.98238
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1387 - accuracy: 0.9525 - val_loss: 0.0698 - val_accuracy: 0.9780
# Epoch 62/200
# 64/81 [======================>.......] - ETA: 0s - loss: 0.1422 - accuracy: 0.9531
# Epoch 62: val_accuracy did not improve from 0.98238
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1403 - accuracy: 0.9548 - val_loss: 0.0705 - val_accuracy: 0.9780
# Epoch 63/200
# 63/81 [======================>.......] - ETA: 0s - loss: 0.1186 - accuracy: 0.9593
# Epoch 63: val_accuracy did not improve from 0.98238
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1295 - accuracy: 0.9579 - val_loss: 0.0713 - val_accuracy: 0.9824
# Epoch 64/200
# 72/81 [=========================>....] - ETA: 0s - loss: 0.1302 - accuracy: 0.9592
# Epoch 64: val_accuracy did not improve from 0.98238
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1255 - accuracy: 0.9611 - val_loss: 0.0597 - val_accuracy: 0.9824
# Epoch 65/200
# 64/81 [======================>.......] - ETA: 0s - loss: 0.1318 - accuracy: 0.9648
# Epoch 65: val_accuracy improved from 0.98238 to 0.98678, saving model to weights.best.hdf5
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1338 - accuracy: 0.9665 - val_loss: 0.0605 - val_accuracy: 0.9868
# Epoch 66/200
# 61/81 [=====================>........] - ETA: 0s - loss: 0.1365 - accuracy: 0.9559
# Epoch 66: val_accuracy did not improve from 0.98678
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1325 - accuracy: 0.9587 - val_loss: 0.0689 - val_accuracy: 0.9824
# Epoch 67/200
# 63/81 [======================>.......] - ETA: 0s - loss: 0.1255 - accuracy: 0.9563
# Epoch 67: val_accuracy did not improve from 0.98678
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1280 - accuracy: 0.9572 - val_loss: 0.0600 - val_accuracy: 0.9824
# Epoch 68/200
# 66/81 [=======================>......] - ETA: 0s - loss: 0.1243 - accuracy: 0.9564
# Epoch 68: val_accuracy did not improve from 0.98678
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1268 - accuracy: 0.9579 - val_loss: 0.0697 - val_accuracy: 0.9780
# Epoch 69/200
# 70/81 [========================>.....] - ETA: 0s - loss: 0.1192 - accuracy: 0.9589
# Epoch 69: val_accuracy did not improve from 0.98678
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1162 - accuracy: 0.9595 - val_loss: 0.0662 - val_accuracy: 0.9824
# Epoch 70/200
# 63/81 [======================>.......] - ETA: 0s - loss: 0.1156 - accuracy: 0.9613
# Epoch 70: val_accuracy did not improve from 0.98678
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1302 - accuracy: 0.9579 - val_loss: 0.0669 - val_accuracy: 0.9780
# Epoch 71/200
# 65/81 [=======================>......] - ETA: 0s - loss: 0.1231 - accuracy: 0.9596
# Epoch 71: val_accuracy did not improve from 0.98678
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1254 - accuracy: 0.9572 - val_loss: 0.0538 - val_accuracy: 0.9824
# Epoch 72/200
# 68/81 [========================>.....] - ETA: 0s - loss: 0.1114 - accuracy: 0.9669
# Epoch 72: val_accuracy did not improve from 0.98678
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1083 - accuracy: 0.9688 - val_loss: 0.0628 - val_accuracy: 0.9824
# Epoch 73/200
# 63/81 [======================>.......] - ETA: 0s - loss: 0.1091 - accuracy: 0.9673
# Epoch 73: val_accuracy did not improve from 0.98678
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1041 - accuracy: 0.9681 - val_loss: 0.0577 - val_accuracy: 0.9824
# Epoch 74/200
# 64/81 [======================>.......] - ETA: 0s - loss: 0.1072 - accuracy: 0.9678
# Epoch 74: val_accuracy did not improve from 0.98678
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1063 - accuracy: 0.9673 - val_loss: 0.0623 - val_accuracy: 0.9824
# Epoch 75/200
# 69/81 [========================>.....] - ETA: 0s - loss: 0.1211 - accuracy: 0.9629
# Epoch 75: val_accuracy did not improve from 0.98678
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1257 - accuracy: 0.9611 - val_loss: 0.0596 - val_accuracy: 0.9824
# Epoch 76/200
# 57/81 [====================>.........] - ETA: 0s - loss: 0.1079 - accuracy: 0.9682
# Epoch 76: val_accuracy did not improve from 0.98678
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1055 - accuracy: 0.9696 - val_loss: 0.0566 - val_accuracy: 0.9824
# Epoch 77/200
# 52/81 [==================>...........] - ETA: 0s - loss: 0.1186 - accuracy: 0.9663
# Epoch 77: val_accuracy did not improve from 0.98678
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1109 - accuracy: 0.9688 - val_loss: 0.0554 - val_accuracy: 0.9824
# Epoch 78/200
# 65/81 [=======================>......] - ETA: 0s - loss: 0.1106 - accuracy: 0.9721
# Epoch 78: val_accuracy did not improve from 0.98678
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1144 - accuracy: 0.9704 - val_loss: 0.0597 - val_accuracy: 0.9824
# Epoch 79/200
# 67/81 [=======================>......] - ETA: 0s - loss: 0.0950 - accuracy: 0.9729
# Epoch 79: val_accuracy did not improve from 0.98678
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1082 - accuracy: 0.9657 - val_loss: 0.0512 - val_accuracy: 0.9824
# Epoch 80/200
# 66/81 [=======================>......] - ETA: 0s - loss: 0.1126 - accuracy: 0.9650
# Epoch 80: val_accuracy did not improve from 0.98678
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1056 - accuracy: 0.9681 - val_loss: 0.0547 - val_accuracy: 0.9824
# Epoch 81/200
# 61/81 [=====================>........] - ETA: 0s - loss: 0.0943 - accuracy: 0.9693
# Epoch 81: val_accuracy did not improve from 0.98678
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0923 - accuracy: 0.9688 - val_loss: 0.0536 - val_accuracy: 0.9824
# Epoch 82/200
# 65/81 [=======================>......] - ETA: 0s - loss: 0.0849 - accuracy: 0.9740
# Epoch 82: val_accuracy did not improve from 0.98678
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0917 - accuracy: 0.9696 - val_loss: 0.0563 - val_accuracy: 0.9824
# Epoch 83/200
# 59/81 [====================>.........] - ETA: 0s - loss: 0.0988 - accuracy: 0.9693
# Epoch 83: val_accuracy did not improve from 0.98678
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1059 - accuracy: 0.9673 - val_loss: 0.0452 - val_accuracy: 0.9868
# Epoch 84/200
# 60/81 [=====================>........] - ETA: 0s - loss: 0.0911 - accuracy: 0.9719
# Epoch 84: val_accuracy did not improve from 0.98678
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0862 - accuracy: 0.9727 - val_loss: 0.0457 - val_accuracy: 0.9868
# Epoch 85/200
# 62/81 [=====================>........] - ETA: 0s - loss: 0.1081 - accuracy: 0.9667
# Epoch 85: val_accuracy did not improve from 0.98678
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1058 - accuracy: 0.9681 - val_loss: 0.0499 - val_accuracy: 0.9824

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['TRAIN', 'VAL'], loc='lower right')
plt.show()

# %%
# Evaluate the model using the TEST dataset
loss, accuracy = model.evaluate(X_test, y_test)
# Out:
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0230 - accuracy: 0.9954

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  """Plots the confusion matrix."""
  if normalize:
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    print("Normalized confusion matrix")
  else:
    print('Confusion matrix, without normalization')

  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=55)
  plt.yticks(tick_marks, classes)
  fmt = '.2f' if normalize else 'd'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j], fmt),
              horizontalalignment="center",
              color="white" if cm[i, j] > thresh else "black")

  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.tight_layout()

# Classify pose in the TEST dataset using the trained model
y_pred = model.predict(X_test)

# Convert the prediction result to class name
y_pred_label = [class_names[i] for i in np.argmax(y_pred, axis=1)]
y_true_label = [class_names[i] for i in np.argmax(y_test, axis=1)]

# Plot the confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))
plot_confusion_matrix(cm,
                      class_names,
                      title ='Confusion Matrix of Pose Classification Model')

# Print the classification report
print('\nClassification Report:\n', classification_report(y_true_label,
                                                          y_pred_label))
# Out:
# 28/28 [==============================] - 0s 1ms/step
# Confusion matrix, without normalization
#
# Classification Report:
#                  precision    recall  f1-score   support
#
#          chair       1.00      1.00      1.00       168
#          cobra       1.00      1.00      1.00       194
#            dog       1.00      1.00      1.00       169
#        no_pose       1.00      1.00      1.00         2
# shoudler_stand       1.00      1.00      1.00         8
#       traingle       0.80      0.80      0.80        10
#           tree       1.00      1.00      1.00       187
#        warrior       0.99      0.99      0.99       139
#
#       accuracy                           1.00       877
#      macro avg       0.97      0.97      0.97       877
#   weighted avg       1.00      1.00      1.00       877

# %%
if is_skip_step_1:
  raise RuntimeError('You must have run step 1 to run this cell.')

# If step 1 was skipped, skip this step.
IMAGE_PER_ROW = 3
MAX_NO_OF_IMAGE_TO_PLOT = 30

# Extract the list of incorrectly predicted poses
false_predict = [id_in_df for id_in_df in range(len(y_test)) \
                if y_pred_label[id_in_df] != y_true_label[id_in_df]]
if len(false_predict) > MAX_NO_OF_IMAGE_TO_PLOT:
  false_predict = false_predict[:MAX_NO_OF_IMAGE_TO_PLOT]

# Plot the incorrectly predicted images
row_count = len(false_predict) // IMAGE_PER_ROW + 1
fig = plt.figure(figsize=(10 * IMAGE_PER_ROW, 10 * row_count))
for i, id_in_df in enumerate(false_predict):
  ax = fig.add_subplot(row_count, IMAGE_PER_ROW, i + 1)
  image_path = os.path.join(images_out_test_folder,
                            df_test.iloc[id_in_df]['file_name'])

  image = cv2.imread(image_path)
  plt.title("Predict: %s; Actual: %s"
            % (y_pred_label[id_in_df], y_true_label[id_in_df]))
  plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
tfjs_model_dir = 'model'

tfjs.converters.save_keras_model(model, tfjs_model_dir)
print('tfjs model saved at ',tfjs_model_dir)
# Out:
# tfjs model saved at  model
